# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

# %%
with open("winequality-red.csv", "r") as file:
    text = file.read()

# %%
text = text.lower()
text = re.sub(r"[^a-zA-Z0-9]", " ", text)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Zainab\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# word tokenization
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['fixed', 'acidity', 'volatile', 'acidity', 'citric', 'acid', 'residual', 'sugar', 'chlorides', 'free', 'sulfur', 'dioxide', 'total', 'sulfur', 'dioxide', 'density', 'ph', 'sulphates', 'alcohol', 'quality', '7', '4', '0', '7', '0', '0', '1', '9', '0', '076', '11', '0', '34', '0', '0', '9978', '3', '51', '0', '56', '9', '4', '5', '7', '8', '0', '88', '0', '0', '2', '6', '0', '098', '25', '0', '67', '0', '0', '9968', '3', '2', '0', '68', '9', '8', '5', '7', '8', '0', '76', '0', '04', '2', '3', '0', '092', '15', '0', '54', '0', '0', '997', '3', '26', '0', '65', '9', '8', '5', '11', '2', '0', '28', '0', '56', '1', '9', '0', '075', '17', '0', '60', '0', '0', '998', '3', '16', '0', '58', '9', '8', '6', '7', '4', '0', '7', '0', '0', '1', '9', '0', '076', '11', '0', '34', '0', '0', '9978', '3', '51', '0', '56', '9', '4', '5', '7', '4', '0', '66', '0', '0', '1', '8', '0', '075', '13', '0', '40', '0', '0', '9978', '3', '51', '0', '56', '9', '4', '5', '7', '9', '0', '6', '0', '06', '1', '6', '0
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Zainab\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# removing noisy(unwanted) words
stop_words = set(stopwords.words("english"))
print(stop_words)
cleaned_tokens = [word for word in tokens if word not in stop_words]
print(cleaned_tokens)
# Out:
# {'t', "you'll", 'own', 'an', 'below', 'through', 'just', 'will', 'having', 'being', 'hadn', 'but', "wasn't", 'won', 'most', 'ours', 'that', "doesn't", 'wouldn', 'this', 'very', "mustn't", "mightn't", 'himself', 'were', 'to', 'didn', 'not', 'than', 'if', 'and', 'above', 'because', 'what', "won't", 'had', "didn't", 'me', 'under', "don't", 'out', 'she', 'all', 'too', "should've", 've', 'he', 'does', 'with', 'be', 'about', 'o', 'it', 'his', 'down', 'off', 'has', 'couldn', 'how', 'are', 'into', 'myself', 'm', 'theirs', 's', 'yourselves', "haven't", 'ma', 'needn', 'shouldn', 'when', 'i', 'each', 'can', 'by', 'there', 'again', 'nor', 'her', 'isn', 'which', 'those', 'themselves', 'ain', 'now', 'after', 'shan', 'doing', 'do', 'while', "shan't", "it's", "needn't", 'no', 'further', 'any', 'who', 'was', 'some', 'yourself', 'only', 'd', "isn't", 'the', 'ourselves', 'up', 'its', 'more', 'other', 'we', 'our', 'aren', 'did', 'until', 'y', 'few', 'been', 'my', 'why', 'hasn', "hadn't", 'don', 'yours',
# ...

# %%
# sentence tokenization
with open("corpus.txt", "r") as file:
    text1 = file.read()
sentences = sent_tokenize(text)
for sentence in sentences:
    print(sentence)
# Out:
# fixed acidity volatile acidity citric acid residual sugar chlorides free sulfur dioxide total sulfur dioxide density ph sulphates alcohol quality 7 4 0 7 0 0 1 9 0 076 11 0 34 0 0 9978 3 51 0 56 9 4 5 7 8 0 88 0 0 2 6 0 098 25 0 67 0 0 9968 3 2 0 68 9 8 5 7 8 0 76 0 04 2 3 0 092 15 0 54 0 0 997 3 26 0 65 9 8 5 11 2 0 28 0 56 1 9 0 075 17 0 60 0 0 998 3 16 0 58 9 8 6 7 4 0 7 0 0 1 9 0 076 11 0 34 0 0 9978 3 51 0 56 9 4 5 7 4 0 66 0 0 1 8 0 075 13 0 40 0 0 9978 3 51 0 56 9 4 5 7 9 0 6 0 06 1 6 0 069 15 0 59 0 0 9964 3 3 0 46 9 4 5 7 3 0 65 0 0 1 2 0 065 15 0 21 0 0 9946 3 39 0 47 10 0 7 7 8 0 58 0 02 2 0 0 073 9 0 18 0 0 9968 3 36 0 57 9 5 7 7 5 0 5 0 36 6 1 0 071 17 0 102 0 0 9978 3 35 0 8 10 5 5 6 7 0 58 0 08 1 8 0 09699999999999999 15 0 65 0 0 9959 3 28 0 54 9 2 5 7 5 0 5 0 36 6 1 0 071 17 0 102 0 0 9978 3 35 0 8 10 5 5 5 6 0 615 0 0 1 6 0 08900000000000001 16 0 59 0 0 9943 3 58 0 52 9 9 5 7 8 0 61 0 29 1 6 0 114 9 0 29 0 0 9974 3 26 1 56 9 1 5 8 9 0 62 0 18 3 8 0 17600000000000002 
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# Load the circular mask image
mask_image = Image.open("circle_mask.png")
mask = np.array(mask_image)

# %%
# wordcloud = WordCloud(width=800, height=800, background_color='black', max_words=100,mask =mask).generate(text)
wordcloud = WordCloud(width=800, height=800, background_color='black', max_words=100,).generate(text)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# for frequency of the words
from nltk.corpus import webtext
from nltk.probability import FreqDist

# %%
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\Zainab\AppData\Roaming\nltk_data...

# %%
wt_words = webtext.words('corpus.txt')
data_analysis = nltk.FreqDist(wt_words)
